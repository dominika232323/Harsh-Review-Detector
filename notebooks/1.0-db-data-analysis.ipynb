# %% [markdown]
# # Loading data

# %%
import pandas as pd

df = pd.read_csv('../data/raw/listings.csv.zst')
df.head()
# Out:
#          id                         listing_url     scrape_id last_scraped  \
# 0  363601.0                                 NaN  2.025031e+13   2025-03-06
# 1  399772.0  https://www.nocarz.pl/rooms/399772           NaN          NaN
# 2  402369.0  https://www.nocarz.pl/rooms/402369  2.025031e+13   2025-03-11
# 3  456333.0                                 NaN  2.025031e+13   2025-03-06
# 4       NaN  https://www.nocarz.pl/rooms/480975  2.025031e+13   2025-03-07
#
#             source                                               name  \
# 0  previous scrape                                                NaN
# 1      city scrape   Rocafort nice & bright 3 stops away Pza Cataluña
# 2              NaN  Great 2 bedr flat close to Las Ramblas city ce...
# 3  previous scrape                              DOUBLE ROOM with WIFI
# 4  previous scrape                      Cozy loft with a big terrace!
#
#                                          description  \
# ...

# %%
df.shape
# Out:
# (1911, 79)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.519000e+03  1.509000e+03  1.536000e+03          1508.000000
# mean   5.647987e+17  2.025031e+13  2.115746e+08            65.423740
# std    5.407685e+17  0.000000e+00  2.054804e+08           150.722089
# min    1.882670e+05  2.025031e+13  1.070400e+04             1.000000
# 25%    3.235801e+07  2.025031e+13  1.491738e+07             2.000000
# 50%    6.448076e+17  2.025031e+13  1.522976e+08             8.000000
# 75%    1.104224e+18  2.025031e+13  3.671728e+08            42.000000
# max    1.368636e+18  2.025031e+13  6.788518e+08           888.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                1520.000000  1545.000000  1533.000000   1559.000000
# mean                   83.500000    41.392682     2.167260      3.368185
# std                   183.851756     0.014190     0.017973      2.160543
# ...

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            1519 non-null   float64
#  1   listing_url                                   1516 non-null   object
#  2   scrape_id                                     1509 non-null   float64
#  3   last_scraped                                  1523 non-null   object
#  4   source                                        1556 non-null   object
#  5   name                                          1512 non-null   object
#  6   description                                   1461 non-null   object
#  7   neighborhood_overview                         780 non-null    object
#  8   picture_url                                   1522 non-null   object
# ...
